# %% [markdown]
# <a href="https://www.kaggle.com/hdvvip111/visual-product-recommendation-system-final-project?scriptVersionId=89154390" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Importing the Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Showing Directories with List

# %%
DATASET_PATH = "/kaggle/input/fashion-product-images-dataset/fashion-dataset/fashion-dataset/"
print(os.listdir(DATASET_PATH))
# Out:
# ['images.csv', 'images', 'styles.csv', 'styles']

# %% [markdown]
# # What is inside the image directory
# ## Observing some sample image

# %%
# what is inside the main directory
list_directory = os.listdir(DATASET_PATH)
print(list_directory)

# each time directory files gets reordered. That's why needed to find where images folder is.
index=0
for i in range (len(list_directory)):
    if list_directory[i]=="images":
        index=i
        break

# what is in the image directory
imageIndex = os.listdir(DATASET_PATH+list_directory[index])
# print(type(imageIndex))
head = 10

# collecting some samples in list
sampleImages = []

# showing indices
for i in range (head):
    sampleImages.append(imageIndex[i])
    print(sampleImages[i])

# choosing some samples to observe
fig=plt.figure()
fig.set_figheight(15)
fig.set_figwidth(15)
axis=[]
row = len(sampleImages)/2
col = row+1

for i in range (len(sampleImages)):
    Image_path=DATASET_PATH+list_directory[index]+"/"+sampleImages[i]
    src = cv2.imread(Image_path)
    image = cv2.cvtColor(src, cv2.COLOR_BGR2RGB) 
    axis.append(fig.add_subplot(row, col, i+1))
    subplot_title=sampleImages[i]
    axis[-1].set_title(subplot_title)  
    plt.imshow(image)

fig.tight_layout()
plt.show()
# Out:
# ['images.csv', 'images', 'styles.csv', 'styles']
# 31973.jpg
# 30778.jpg
# 19812.jpg
# 22735.jpg
# 38246.jpg
# 16916.jpg
# 52876.jpg
# 39500.jpg
# 44758.jpg
# 59454.jpg

# %% [markdown]
# # Problem1-We have no labeled data. Exploring styles.csv for more info.

# %%
df = pd.read_csv(DATASET_PATH + "styles.csv", nrows=50000, error_bad_lines=False)
df.head(10)
# Out:
# b'Skipping line 6044: expected 10 fields, saw 11\nSkipping line 6569: expected 10 fields, saw 11\nSkipping line 7399: expected 10 fields, saw 11\nSkipping line 7939: expected 10 fields, saw 11\nSkipping line 9026: expected 10 fields, saw 11\nSkipping line 10264: expected 10 fields, saw 11\nSkipping line 10427: expected 10 fields, saw 11\nSkipping line 10905: expected 10 fields, saw 11\nSkipping line 11373: expected 10 fields, saw 11\nSkipping line 11945: expected 10 fields, saw 11\nSkipping line 14112: expected 10 fields, saw 11\nSkipping line 14532: expected 10 fields, saw 11\nSkipping line 15076: expected 10 fields, saw 12\nSkipping line 29906: expected 10 fields, saw 11\nSkipping line 31625: expected 10 fields, saw 11\nSkipping line 33020: expected 10 fields, saw 11\nSkipping line 35748: expected 10 fields, saw 11\nSkipping line 35962: expected 10 fields, saw 11\nSkipping line 37770: expected 10 fields, saw 11\nSkipping line 38105: expected 10 fields, saw 11\nSkipping line 38275: expected 10 fields, saw 11\nSkipping line 38404: expected 10 fields, saw 12\n'
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 5   1855    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 6  30805    Men        Apparel     Topwear       Shirts      Green  Summer
# 7  26960  Women        Apparel     Topwear       Shirts     Purple  Summer
# 8  29114    Men    Accessories       Socks        Socks  Navy Blue  Summer
# 9  30039    Men    Accessories     Watches      Watches      Black  Winter
#
#      year   usage                             productDisplayName
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt
# 1  2012.0  Casual             Peter England Men Party Blue Jeans
# 2  2016.0  Casual                       Titan Women Silver Watch
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants
# 4  2012.0  Casual                          Puma Men Grey T-shirt
# 5  2011.0  Casual           Inkfruit Mens Chain Reaction T-shirt
# 6  2012.0  Ethnic               Fabindia Men Striped Green Shirt
# 7  2012.0  Casual                  Jealous 21 Women Purple Shirt
# 8  2012.0  Casual                       Puma Men Pack of 3 Socks
# 9  2016.0  Casual                         Skagen Men Black Watch

# %% [markdown]
# # Image id matches with styles.csv file Id column.
# ## For ease of access, adding another column naming 'id.jpg'

# %%
df['image'] = df.apply(lambda row: str(row['id']) + ".jpg", axis=1)
df.head(10)
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 5   1855    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 6  30805    Men        Apparel     Topwear       Shirts      Green  Summer
# 7  26960  Women        Apparel     Topwear       Shirts     Purple  Summer
# 8  29114    Men    Accessories       Socks        Socks  Navy Blue  Summer
# 9  30039    Men    Accessories     Watches      Watches      Black  Winter
#
#      year   usage                             productDisplayName      image
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt  15970.jpg
# 1  2012.0  Casual             Peter England Men Party Blue Jeans  39386.jpg
# 2  2016.0  Casual                       Titan Women Silver Watch  59263.jpg
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants  21379.jpg
# 4  2012.0  Casual                          Puma Men Grey T-shirt  53759.jpg
# 5  2011.0  Casual           Inkfruit Mens Chain Reaction T-shirt   1855.jpg
# 6  2012.0  Ethnic               Fabindia Men Striped Green Shirt  30805.jpg
# 7  2012.0  Casual                  Jealous 21 Women Purple Shirt  26960.jpg
# 8  2012.0  Casual                       Puma Men Pack of 3 Socks  29114.jpg
# 9  2016.0  Casual                         Skagen Men Black Watch  30039.jpg

# %% [markdown]
# # Building another dataframe with columns- image and article type

# %%
augmentedDataframe = pd.DataFrame({
    'filename': df['image'],
    'type': df['articleType']
})

# total number of entries in the dataframe
total_row = len(augmentedDataframe)
print('total row count: ', total_row)

augmentedDataframe.head(10)
# Out:
# total row count:  44424
#     filename         type
# 0  15970.jpg       Shirts
# 1  39386.jpg        Jeans
# 2  59263.jpg      Watches
# 3  21379.jpg  Track Pants
# 4  53759.jpg      Tshirts
# 5   1855.jpg      Tshirts
# 6  30805.jpg       Shirts
# 7  26960.jpg       Shirts
# 8  29114.jpg        Socks
# 9  30039.jpg      Watches

# %% [markdown]
# > # Created a list with unique values And added a column with their specified element position

# %%
unique_types = augmentedDataframe['type'].unique().tolist()
total_class = len(unique_types)
print(total_class)
print(unique_types)
print(unique_types[0])
print(unique_types.index(unique_types[0]))
augmentedDataframe['number_types'] = augmentedDataframe['type'].apply(lambda x: unique_types.index(x) if x in unique_types else 0)
augmentedDataframe.head(10)
# Out:
# 143
# ['Shirts', 'Jeans', 'Watches', 'Track Pants', 'Tshirts', 'Socks', 'Casual Shoes', 'Belts', 'Flip Flops', 'Handbags', 'Tops', 'Bra', 'Sandals', 'Shoe Accessories', 'Sweatshirts', 'Deodorant', 'Formal Shoes', 'Bracelet', 'Lipstick', 'Flats', 'Kurtas', 'Waistcoat', 'Sports Shoes', 'Shorts', 'Briefs', 'Sarees', 'Perfume and Body Mist', 'Heels', 'Sunglasses', 'Innerwear Vests', 'Pendant', 'Nail Polish', 'Laptop Bag', 'Scarves', 'Rain Jacket', 'Dresses', 'Night suits', 'Skirts', 'Wallets', 'Blazers', 'Ring', 'Kurta Sets', 'Clutches', 'Shrug', 'Backpacks', 'Caps', 'Trousers', 'Earrings', 'Camisoles', 'Boxers', 'Jewellery Set', 'Dupatta', 'Capris', 'Lip Gloss', 'Bath Robe', 'Mufflers', 'Tunics', 'Jackets', 'Trunk', 'Lounge Pants', 'Face Wash and Cleanser', 'Necklace and Chains', 'Duffel Bag', 'Sports Sandals', 'Foundation and Primer', 'Sweaters', 'Free Gifts', 'Trolley Bag', 'Tracksuits', 'Swimwear', 'Shoe Laces', 'Fragrance Gift Set', 'Bangle', 'Nightdress', 'Ties', 'Baby Dolls', 'Leggings', 'Highlighter and Blush', 'Travel Accessory', 'Kurtis', 'Mobile Pouch', 'Messenger Bag', 'Lip Care', 'Face Moisturisers', 'Compact', 'Eye Cream', 'Accessory Gift Set', 'Beauty Accessory', 'Jumpsuit', 'Kajal and Eyeliner', 'Water Bottle', 'Suspenders', 'Lip Liner', 'Robe', 'Salwar and Dupatta', 'Patiala', 'Stockings', 'Eyeshadow', 'Headband', 'Tights', 'Nail Essentials', 'Churidar', 'Lounge Tshirts', 'Face Scrub and Exfoliator', 'Lounge Shorts', 'Gloves', 'Mask and Peel', 'Wristbands', 'Tablet Sleeve', 'Ties and Cufflinks', 'Footballs', 'Stoles', 'Shapewear', 'Nehru Jackets', 'Salwar', 'Cufflinks', 'Jeggings', 'Hair Colour', 'Concealer', 'Rompers', 'Body Lotion', 'Sunscreen', 'Booties', 'Waist Pouch', 'Hair Accessory', 'Rucksacks', 'Basketballs', 'Lehenga Choli', 'Clothing Set', 'Mascara', 'Toner', 'Cushion Covers', 'Key chain', 'Makeup Remover', 'Lip Plumper', 'Umbrellas', 'Face Serum and Gel', 'Hat', 'Mens Grooming Kit', 'Rain Trousers', 'Body Wash and Scrub', 'Suits', 'Ipad']
# Shirts
# 0
#     filename         type  number_types
# 0  15970.jpg       Shirts             0
# 1  39386.jpg        Jeans             1
# 2  59263.jpg      Watches             2
# 3  21379.jpg  Track Pants             3
# 4  53759.jpg      Tshirts             4
# 5   1855.jpg      Tshirts             4
# 6  30805.jpg       Shirts             0
# 7  26960.jpg       Shirts             0
# 8  29114.jpg        Socks             5
# 9  30039.jpg      Watches             2

# %%
augmentedDataframe['type'].value_counts().head(50)
# Out:
# Tshirts                  7067
# Shirts                   3217
# Casual Shoes             2845
# Watches                  2542
# Sports Shoes             2036
# Kurtas                   1844
# Tops                     1762
# Handbags                 1759
# Heels                    1323
# Sunglasses               1073
# Wallets                   936
# Flip Flops                914
# Sandals                   897
# Briefs                    849
# Belts                     813
# Backpacks                 724
# Socks                     686
# Formal Shoes              637
# Perfume and Body Mist     613
# Jeans                     609
# Shorts                    547
# Trousers                  530
# Flats                     500
# Bra                       477
# Dresses                   464
# Sarees                    427
# Earrings                  416
# Deodorant                 347
# Nail Polish               329
# Lipstick                  315
# Track Pants               304
# Clutches                  290
# Sweatshirts               285
# Caps                      283
# Sweaters                  277
# Ties                      263
# Jackets                   258
# Innerwear Vests           242
# Kurtis                    234
# Tunics                    229
# Nightdress                189
# Leggings                  177
# Pendant                   176
# Capris                    175
# Necklace and Chains       160
# Lip Gloss                 144
# Night suits               141
# Trunk                     140
# Skirts                    128
# Scarves                   119
# Name: type, dtype: int64

# %% [markdown]
# # Here total counting length is 108. Total number of type classes available 108.

# %%
plt.figure(figsize=(20,5))
augmentedDataframe['type'].value_counts().plot(kind='bar',x='type',y='filename')
plt.show()

# %% [markdown]
# # Starting with train and test data
# ## Inserting Image and Labels in numpy array

# %% [markdown]
# # Utility Function to get images and inserted into image array
# ## Start and Stop parameters will be useful train and test separation
#
# ## Here all X=image_data, Y=label_data

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
# Out:
# /opt/conda/lib/python3.7/site-packages/tqdm/std.py:666: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
def getData(start,stop):
    x_data = []
    y_data = []
    Rej_imgs = []
    #start = 0 #setting start parameter
    #stop = int(0.001*total_row) #setting stop parameter 
    
    for i in tqdm(range(start, stop)): 
        Image_path=DATASET_PATH+list_directory[index]+"/"+augmentedDataframe.loc[i,'filename']
#         print(augmentedDataframe.loc[i,'filename'])
        image = cv2.imread(Image_path,cv2.IMREAD_GRAYSCALE)
        try:
            resized_img = cv2.resize(image, dsize=(28, 28))
        except:
            print("Rejected Image: "+augmentedDataframe.loc[i,'filename'])
            Rej_imgs.append(augmentedDataframe.loc[i,'filename'])
            continue
        x_data.append(resized_img) 
        y_values = augmentedDataframe.loc[i,'number_types'] # earlier it was type
        y_data.append(y_values)
                
    return x_data, y_data,Rej_imgs

# %% [markdown]
# # Test of the function

# %%
X=[]
Y=[]
# for now start=0,stop=(0.001*total_row)
# total_row=count of rows in augmented data frame
start = 0
stop = int(0.001*total_row) # testing with 0.1% image of the dataset
X,Y,Rej_imgs =getData(start,stop)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=44.0), HTML(value='')))

# %%
def img_path(img):
    return DATASET_PATH+"/images/"+img

# %%
def load_image(img, resized_fac = 0.1):
    img     = cv2.imread(img_path(img))
    w, h, _ = img.shape
    resized = cv2.resize(img, (int(h*resized_fac), int(w*resized_fac)), interpolation = cv2.INTER_AREA)
    return resized

# %%
img_array = load_image(df.loc[0]['image'])
plt.imshow(cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB))

# %%
print(type(X))
# print(X[0])
plt.title(unique_types[Y[0]])
plt.imshow(X[0])
# Out:
# <class 'list'>

# %% [markdown]
# # Adding all the images to numpy array
# > # X=Image Array
# > # Y=Image Label Array

# %%
X=[]
Y=[]
start = 0
stop = total_row
X,Y,Rej_imgs=getData(start,stop)

# conversion into numpy array
X = np.array(X).reshape(-1, 28,28,1)
Y = np.array(Y)

# normalizing
X = X/255

# processing Y_train for dimension matching
Y = Y.reshape(len(X),)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=44424.0), HTML(value='')))
# Rejected Image: 39403.jpg
# Rejected Image: 39410.jpg
# Rejected Image: 39401.jpg
# Rejected Image: 39425.jpg
# Rejected Image: 12347.jpg

# %%
print('Image Data Shape: ',X.shape)
print('Label Data Shape: ',Y.shape)
# Out:
# Image Data Shape:  (44419, 28, 28, 1)
# Label Data Shape:  (44419,)

# %% [markdown]
# # Now we got Image and Label added in the arrays. Next will be Spliting both train and test data.

# %% [markdown]
# > # Train,Test Division into 90:10
# > # Train,Validation Division into 90:10
# > Train, Validation, Test Percentage 80:10:10

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.1, random_state = 500)

# %%
print('Train Image Data Shape: ',X_train.shape)
print('Train Label Data Shape: ',Y_train.shape)
print('Test Image Data Shape: ',X_test.shape)
print('Test Label Data Shape: ',Y_test.shape)
# Out:
# Train Image Data Shape:  (39977, 28, 28, 1)
# Train Label Data Shape:  (39977,)
# Test Image Data Shape:  (4442, 28, 28, 1)
# Test Label Data Shape:  (4442,)

# %%
X_train, X_validate, Y_train, Y_validate = train_test_split(X_train, Y_train, test_size = 0.1, random_state = 500)

# %%
print('Train Image Data Shape: ',X_train.shape)
print('Train Label Data Shape: ',Y_train.shape)
print('Validation Image Data Shape: ',X_validate.shape)
print('Validation Label Data Shape: ',Y_validate.shape)
# Out:
# Train Image Data Shape:  (35979, 28, 28, 1)
# Train Label Data Shape:  (35979,)
# Validation Image Data Shape:  (3998, 28, 28, 1)
# Validation Label Data Shape:  (3998,)

# %% [markdown]
# > ## Splitting done with train and test and validation set.

# %% [markdown]
# # CNN Model Create

# %% [markdown]
# ># Importing Libraries

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Flatten, Dense, Dropout, LayerNormalization
from tensorflow.keras.layers import ReLU
from tensorflow.keras.optimizers import Adam
import os
import tensorflow as tf
import datetime, os
from tensorflow.keras.callbacks import TensorBoard

# %% [markdown]
# > # Creating sequential model with three layers

# %%
def build_model():
    cnn_model = Sequential()
    cnn_model.add(Conv2D(32, (3, 3), input_shape = (28,28,1)))
    cnn_model.add(LayerNormalization())
    cnn_model.add(ReLU())
    cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
    cnn_model.add(Dropout(0.25))

    cnn_model.add(Conv2D(64, (3, 3)))
    cnn_model.add(LayerNormalization())
    cnn_model.add(ReLU())
    cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
    cnn_model.add(Dropout(0.25))

    cnn_model.add(Conv2D(128, (3, 3)))
    cnn_model.add(LayerNormalization())
    cnn_model.add(ReLU())
    cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
    cnn_model.add(Dropout(0.25))

    cnn_model.add(Flatten())
    cnn_model.add(Dense(units = 512))
    cnn_model.add(LayerNormalization())
    cnn_model.add(ReLU())
    cnn_model.add(Dense(units = 512))
    cnn_model.add(LayerNormalization())
    cnn_model.add(ReLU())
    cnn_model.add(Dropout(0.25))
    
    cnn_model.add(Dense(units = total_class, activation = 'softmax'))
    return cnn_model

# %%
model=build_model()

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# layer_normalization (LayerNo (None, 26, 26, 32)        64
# _________________________________________________________________
# re_lu (ReLU)                 (None, 26, 26, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 11, 11, 64)        128
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 11, 11, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# layer_normalization_2 (Layer (None, 3, 3, 128)         256
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 3, 3, 128)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# layer_normalization_3 (Layer (None, 512)               1024
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# layer_normalization_4 (Layer (None, 512)               1024
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 143)               73359
# =================================================================
# Total params: 497,231
# Trainable params: 497,231
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def train_model(model):
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
    opt = Adam(learning_rate=1e-4)
    model.compile( loss ='sparse_categorical_crossentropy', optimizer='adam' ,metrics=['accuracy'])
    history = model.fit(X_train, Y_train, batch_size = 256, epochs = 150, verbose = 1,
                        callbacks=[callback], 
                        validation_data = (X_validate, Y_validate))
    
    return history
#     model.fit(X_train, Y_train, epochs=50, batch_size=512, validation_split=0.2)

# %%
training_history = train_model(model)
# Out:
# Epoch 1/150
# 141/141 [==============================] - 3s 23ms/step - loss: 3.3159 - accuracy: 0.2014 - val_loss: 2.2447 - val_accuracy: 0.3874
# Epoch 2/150
# 141/141 [==============================] - 3s 20ms/step - loss: 1.9419 - accuracy: 0.4546 - val_loss: 1.3822 - val_accuracy: 0.6118
# Epoch 3/150
# 141/141 [==============================] - 3s 20ms/step - loss: 1.5280 - accuracy: 0.5590 - val_loss: 1.1802 - val_accuracy: 0.6533
# Epoch 4/150
# 141/141 [==============================] - 3s 20ms/step - loss: 1.3507 - accuracy: 0.6035 - val_loss: 1.1012 - val_accuracy: 0.6741
# Epoch 5/150
# 141/141 [==============================] - 3s 20ms/step - loss: 1.2510 - accuracy: 0.6292 - val_loss: 1.0178 - val_accuracy: 0.6941
# Epoch 6/150
# 141/141 [==============================] - 3s 20ms/step - loss: 1.1865 - accuracy: 0.6468 - val_loss: 0.9865 - val_accuracy: 0.7031
# Epoch 7/150
# 141/141 [==============================] - 3s 21ms/step - loss: 1.1185 - accuracy: 0.6642 - val_loss: 0.9780 - val_accuracy: 0.7046
# Epoch 8/150
# 141/141 [==============================] - 3s 20ms/step - loss: 1.0857 - accuracy: 0.6710 - val_loss: 0.9205 - val_accuracy: 0.7244
# Epoch 9/150
# 141/141 [==============================] - 3s 20ms/step - loss: 1.0395 - accuracy: 0.6833 - val_loss: 0.8958 - val_accuracy: 0.7324
# Epoch 10/150
# 141/141 [==============================] - 3s 21ms/step - loss: 1.0032 - accuracy: 0.6909 - val_loss: 0.8991 - val_accuracy: 0.7261
# Epoch 11/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.9876 - accuracy: 0.6956 - val_loss: 0.8579 - val_accuracy: 0.7381
# Epoch 12/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.9623 - accuracy: 0.7037 - val_loss: 0.8514 - val_accuracy: 0.7394
# Epoch 13/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.9426 - accuracy: 0.7076 - val_loss: 0.8551 - val_accuracy: 0.7416
# Epoch 14/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.9131 - accuracy: 0.7144 - val_loss: 0.8014 - val_accuracy: 0.7506
# Epoch 15/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.9028 - accuracy: 0.7161 - val_loss: 0.8056 - val_accuracy: 0.7499
# Epoch 16/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.8814 - accuracy: 0.7246 - val_loss: 0.7974 - val_accuracy: 0.7491
# Epoch 17/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.8622 - accuracy: 0.7275 - val_loss: 0.7863 - val_accuracy: 0.7586
# Epoch 18/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.8488 - accuracy: 0.7330 - val_loss: 0.7683 - val_accuracy: 0.7651
# Epoch 19/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.8334 - accuracy: 0.7372 - val_loss: 0.7698 - val_accuracy: 0.7666
# Epoch 20/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.8125 - accuracy: 0.7412 - val_loss: 0.7602 - val_accuracy: 0.7674
# Epoch 21/150
# 141/141 [==============================] - 3s 21ms/step - loss: 0.8054 - accuracy: 0.7448 - val_loss: 0.7730 - val_accuracy: 0.7651
# Epoch 22/150
# 141/141 [==============================] - 3s 21ms/step - loss: 0.7901 - accuracy: 0.7479 - val_loss: 0.7507 - val_accuracy: 0.7644
# Epoch 23/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.7840 - accuracy: 0.7477 - val_loss: 0.7474 - val_accuracy: 0.7746
# Epoch 24/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.7724 - accuracy: 0.7522 - val_loss: 0.7308 - val_accuracy: 0.7751
# Epoch 25/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.7677 - accuracy: 0.7550 - val_loss: 0.7411 - val_accuracy: 0.7734
# Epoch 26/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.7565 - accuracy: 0.7537 - val_loss: 0.7244 - val_accuracy: 0.7761
# Epoch 27/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.7544 - accuracy: 0.7587 - val_loss: 0.7501 - val_accuracy: 0.7724
# Epoch 28/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.7386 - accuracy: 0.7604 - val_loss: 0.7116 - val_accuracy: 0.7771
# Epoch 29/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.7280 - accuracy: 0.7601 - val_loss: 0.7242 - val_accuracy: 0.7754
# Epoch 30/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.7239 - accuracy: 0.7628 - val_loss: 0.7055 - val_accuracy: 0.7799
# Epoch 31/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.7138 - accuracy: 0.7643 - val_loss: 0.7315 - val_accuracy: 0.7789
# Epoch 32/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.7092 - accuracy: 0.7693 - val_loss: 0.7164 - val_accuracy: 0.7809
# Epoch 33/150
# 141/141 [==============================] - 3s 21ms/step - loss: 0.7017 - accuracy: 0.7708 - val_loss: 0.7005 - val_accuracy: 0.7844
# Epoch 34/150
# 141/141 [==============================] - 3s 21ms/step - loss: 0.6999 - accuracy: 0.7674 - val_loss: 0.6943 - val_accuracy: 0.7861
# Epoch 35/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6908 - accuracy: 0.7741 - val_loss: 0.7107 - val_accuracy: 0.7831
# Epoch 36/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6906 - accuracy: 0.7741 - val_loss: 0.6994 - val_accuracy: 0.7919
# Epoch 37/150
# 141/141 [==============================] - 3s 21ms/step - loss: 0.6714 - accuracy: 0.7781 - val_loss: 0.7004 - val_accuracy: 0.7864
# Epoch 38/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6663 - accuracy: 0.7806 - val_loss: 0.6802 - val_accuracy: 0.7926
# Epoch 39/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6616 - accuracy: 0.7804 - val_loss: 0.6957 - val_accuracy: 0.7904
# Epoch 40/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6541 - accuracy: 0.7840 - val_loss: 0.6868 - val_accuracy: 0.7916
# Epoch 41/150
# 141/141 [==============================] - 3s 21ms/step - loss: 0.6461 - accuracy: 0.7869 - val_loss: 0.6835 - val_accuracy: 0.7936
# Epoch 42/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6483 - accuracy: 0.7840 - val_loss: 0.6867 - val_accuracy: 0.7941
# Epoch 43/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6445 - accuracy: 0.7840 - val_loss: 0.6947 - val_accuracy: 0.7896
# Epoch 44/150
# 141/141 [==============================] - 3s 21ms/step - loss: 0.6427 - accuracy: 0.7881 - val_loss: 0.7019 - val_accuracy: 0.7851
# Epoch 45/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6382 - accuracy: 0.7862 - val_loss: 0.6809 - val_accuracy: 0.7926
# Epoch 46/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6274 - accuracy: 0.7902 - val_loss: 0.6898 - val_accuracy: 0.7926
# Epoch 47/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6236 - accuracy: 0.7893 - val_loss: 0.6848 - val_accuracy: 0.7956
# Epoch 48/150
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6173 - accuracy: 0.7925 - val_loss: 0.6888 - val_accuracy: 0.7914

# %% [markdown]
# # Model Evaluation

# %%
import pickle
with open('./training_history_pickle', "wb") as pkl_file:
        pickle.dump(training_history.history, pkl_file, pickle.HIGHEST_PROTOCOL)

# %%
with open('./training_history_pickle', "rb") as pkl_file:
        training_history_load = pickle.load(pkl_file)

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.plot(training_history_load['loss'], label='Train Loss')
plt.plot(training_history_load['val_loss'], label='Test Loss')
plt.legend()
plt.grid()
plt.title('Loss evaluation')

plt.subplot(2, 2, 2)
plt.plot(training_history_load['accuracy'], label='Train accuracy')
plt.plot(training_history_load['val_accuracy'], label='Test accuracy')
plt.legend()
plt.grid()
plt.title('Accuracy evaluation')
# Out:
# Text(0.5, 1.0, 'Accuracy evaluation')

# %% [markdown]
# ## Saving Model

# %%
model.save('visual_product_recommend.h5')

# %% [markdown]
# ## Load Model

# %%
from keras import models

# %%
pretrained_model = models.load_model('./visual_product_recommend.h5')
pretrained_model

# %% [markdown]
# # Predictions for the test data

# %%
predicted_classes = model.predict_classes(X_test)

# %%
import sklearn.metrics as metrics
print(metrics.classification_report(y_true=Y_test, y_pred=predicted_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.92      0.86       295
#            1       0.70      0.91      0.79        58
#            2       0.94      0.99      0.96       267
#            3       0.84      0.74      0.79        35
#            4       0.85      0.92      0.88       686
#            5       0.87      0.91      0.89        64
#            6       0.83      0.61      0.70       271
#            7       0.97      1.00      0.99        66
#            8       0.76      0.89      0.82       102
#            9       0.87      0.93      0.90       182
#           10       0.59      0.49      0.54       178
#           11       0.89      0.96      0.92        50
#           12       0.80      0.71      0.75        97
#           13       1.00      0.50      0.67         2
#           14       0.64      0.30      0.41        30
#           15       0.76      0.90      0.83        29
#           16       0.72      0.86      0.78        72
#           17       0.64      0.88      0.74         8
#           18       0.90      0.90      0.90        39
#           19       0.57      0.22      0.32        58
#           20       0.67      0.94      0.78       182
#           21       1.00      0.50      0.67         2
#           22       0.68      0.91      0.78       201
#           23       0.76      0.77      0.77        53
#           24       0.86      0.92      0.89        77
#           25       0.83      0.97      0.90        40
#           26       0.74      0.74      0.74        57
#           27       0.71      0.82      0.76       130
#           28       0.99      0.99      0.99       124
#           29       0.80      0.44      0.57        27
#           30       0.83      0.31      0.45        16
#           31       0.94      1.00      0.97        34
#           32       0.57      0.50      0.53         8
#           33       0.56      0.45      0.50        11
#           34       0.00      0.00      0.00         3
#           35       0.59      0.33      0.42        52
#           36       1.00      0.93      0.96        14
#           37       0.80      0.62      0.70        13
#           38       0.84      0.94      0.88        93
#           40       0.86      0.60      0.71        10
#           41       0.67      0.62      0.64        13
#           42       0.57      0.55      0.56        22
#           44       0.83      0.92      0.87        60
#           45       0.96      0.93      0.95        29
#           46       0.82      0.73      0.77        62
#           47       0.96      0.89      0.92        54
#           48       0.00      0.00      0.00         3
#           49       1.00      0.50      0.67         4
#           50       0.60      0.75      0.67         4
#           51       0.82      0.56      0.67        16
#           52       0.60      0.38      0.46        16
#           53       0.93      0.74      0.82        19
#           54       0.00      0.00      0.00         1
#           55       0.50      0.29      0.36         7
#           56       0.00      0.00      0.00        22
#           57       0.65      0.35      0.46        48
#           58       0.73      0.50      0.59        16
#           59       0.20      0.50      0.29         2
#           60       0.20      1.00      0.33         1
#           61       0.52      0.93      0.67        14
#           62       0.86      0.75      0.80         8
#           63       0.00      0.00      0.00         3
#           64       0.40      0.40      0.40         5
#           65       0.50      0.22      0.30        32
#           66       0.00      0.00      0.00         8
#           67       0.00      0.00      0.00         1
#           68       0.67      1.00      0.80         2
#           69       0.00      0.00      0.00         1
#           71       0.67      0.67      0.67         3
#           72       0.62      0.83      0.71         6
#           73       0.56      0.50      0.53        20
#           74       1.00      0.97      0.99        35
#           75       0.00      0.00      0.00         1
#           76       1.00      0.53      0.69        17
#           77       0.80      0.57      0.67         7
#           78       0.00      0.00      0.00         3
#           79       0.43      0.13      0.20        23
#           80       0.00      0.00      0.00         4
#           81       0.00      0.00      0.00         1
#           82       0.50      0.50      0.50         2
#           83       1.00      0.33      0.50         6
#           84       1.00      0.80      0.89         5
#           86       0.89      1.00      0.94         8
#           89       0.48      0.79      0.59        14
#           90       0.00      0.00      0.00         1
#           91       1.00      0.75      0.86         4
#           92       0.25      0.14      0.18         7
#           95       1.00      1.00      1.00         2
#           96       0.75      1.00      0.86         3
#           97       1.00      0.43      0.60         7
#          100       0.00      0.00      0.00         3
#          101       0.00      0.00      0.00         0
#          103       0.00      0.00      0.00         1
#          104       0.00      0.00      0.00         3
#          105       0.00      0.00      0.00         1
#          106       0.00      0.00      0.00         3
#          107       1.00      1.00      1.00         1
#          108       0.00      0.00      0.00         2
#          110       0.00      0.00      0.00         1
#          111       0.80      0.40      0.53        10
#          112       0.00      0.00      0.00         2
#          114       1.00      1.00      1.00         2
#          115       0.80      1.00      0.89         8
#          116       0.14      0.33      0.20         3
#          118       0.00      0.00      0.00         2
#          121       1.00      1.00      1.00         1
#          122       0.50      0.50      0.50         2
#          125       0.00      0.00      0.00         1
#          126       0.50      1.00      0.67         1
#          127       0.00      0.00      0.00         2
#          128       0.00      0.00      0.00         2
#          129       0.00      0.00      0.00         1
#          132       0.00      0.00      0.00         1
#          135       1.00      1.00      1.00         1
#
#     accuracy                           0.79      4442
#    macro avg       0.57      0.53      0.53      4442
# weighted avg       0.78      0.79      0.78      4442
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#PC=PredictedClass #TC=TrueClass
L = 5
W = 5
fig, axes = plt.subplots(L, W, figsize = (12,12))
axes = axes.ravel()

for i in np.arange(0, L * W):  
    axes[i].imshow(X_test[i].reshape(28,28))
    axes[i].set_title(f"PC = {unique_types[predicted_classes[i]]}\n TC = {unique_types[Y_test[i]]}") #predicted_classes[i]:0.1f #Y_test[i]:0.1f
    axes[i].axis('off')
plt.subplots_adjust(wspace=0.5)

# %% [markdown]
# # Single Image Prediction & Find the Label of the Image

# %%
#augmentedDataframe.head(10)

# %%
def load_image(i):
    Image_path=DATASET_PATH+list_directory[index]+"/"+augmentedDataframe.loc[i,'filename']
    Image_id=augmentedDataframe.loc[i,'filename'].split(".")
    res=Image_id[0]
    image = cv2.imread(Image_path,cv2.IMREAD_COLOR)
    resized_img = cv2.resize(image, dsize=(224, 224))
    return resized_img,res

# %%
img,img_id = load_image(105)
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.title(img_id)
plt.imshow(img)

# %%
def make_prediction(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
    resized_img = cv2.resize(img, dsize=(28, 28))
    x_data = np.array(resized_img).reshape(-1, 28,28,1)
    x_data=x_data/255
#     print(x_data)
#     print(x_data.shape)
    result=pretrained_model.predict(x_data)
#     print(type(result))
#     print(np.argmax(result))
    return x_data,unique_types[np.argmax(result)]

# %%
numpy_image,result=make_prediction(img)
print(result)
# Out:
# Casual Shoes

# %%
#df.head(10)

# %% [markdown]
# # Starting Check for Similarity

# %%
typeList=[]
for i, row in df.iterrows(): 
    if(row["articleType"]==result):
        #print(row["id"],row["articleType"])
        if(img_id!=str(row["id"])):
            typeList.append(row['id'])

# %%
print(typeList)
# Out:
# [9204, 39988, 22198, 29570, 26538, 49495, 19311, 23849, 24250, 15517, 4140, 6425, 42270, 32751, 39943, 22705, 50741, 20856, 19772, 5896, 49492, 9031, 59056, 15379, 19329, 39944, 36130, 44510, 22702, 30233, 6422, 12507, 42045, 24257, 15510, 20894, 40971, 7364, 13073, 39972, 16165, 22162, 17043, 10266, 4343, 47501, 22196, 23878, 26536, 54740, 13087, 32552, 39986, 12509, 23840, 24259, 18665, 20893, 9000, 50748, 11976, 3505, 13080, 32555, 39981, 15377, 5898, 22191, 26531, 6413, 11949, 5050, 22165, 49468, 10295, 22733, 13074, 39975, 22501, 37241, 3551, 42020, 4122, 21740, 3797, 44747, 14498, 38652, 23814, 17813, 18403, 12905, 5699, 24669, 47109, 44778, 39310, 31941, 13649, 34857, 33840, 3790, 44740, 7754, 2828, 13685, 26562, 6672, 21747, 20695, 6440, 24463, 3556, 8982, 37246, 2817, 33847, 2219, 49060, 31946, 54519, 18404, 12902, 23679, 17814, 34859, 41452, 3594, 50376, 44776, 17683, 3560, 5697, 53735, 14496, 4113, 26554, 44749, 9091, 6811, 30258, 14491, 26553, 53732, 47100, 4742, 5690, 44771, 17684, 3593, 34634, 35382, 33849, 57530, 6816, 3558, 54528, 37248, 38664, 24835, 32950, 49435, 34861, 39742, 41832, 9096, 8978, 46825, 50749, 23841, 24258, 12508, 20892, 9001, 4183, 11948, 49469, 22164, 22500, 13075, 39974, 7396, 13081, 39980, 32554, 6412, 21715, 15520, 5899, 26530, 22190, 40970, 20895, 45866, 15518, 46841, 39342, 24260, 26537, 12702, 22197, 6415, 15715, 10267, 54741, 13086, 39987, 32553, 13072, 39973, 7365, 4184, 22163, 5897, 49493, 29576, 9202, 46883, 9030, 12995, 28662, 50778, 10635, 32757, 42044, 24256, 42276, 12506, 11979, 50747, 36131, 39945, 20868, 22703, 5864, 49460, 39989, 9205, 46884, 49494, 26539, 29571, 22199, 22536, 39942, 22704, 14430, 42271, 42043, 4141, 24251, 46087, 10632, 34635, 23682, 3592, 44770, 35383, 57531, 41454, 33848, 14490, 26552, 6470, 4743, 5691, 49434, 34860, 41833, 9097, 54529, 37249, 56870, 3559, 32951, 21748, 24666, 53734, 3561, 24454, 5696, 56410, 14497, 7797, 34090, 26555, 35384, 41453, 22101, 13646, 34858, 44777, 17682, 50377, 3595, 6448, 17823, 30259, 6810, 31985, 41834, 9090, 3798, 44748, 49433, 57509, 6441, 13684, 26563, 54527, 37247, 8983, 3557, 44741, 8977, 49608, 12903, 18405, 42019, 34851, 33846, 49061, 49059, 44746, 8984, 3550, 30257, 54520, 37240, 42021, 21741, 4123, 6446, 44779, 33841, 34856, 38653, 14499, 7799, 23815, 24668, 18402, 5698, 47248, 4852, 2399, 22841, 43876, 10174, 57481, 15250, 59943, 3610, 35465, 6362, 21091, 2504, 13361, 33766, 20715, 36442, 24187, 13537, 34749, 28316, 15892, 13359, 22846, 43871, 2964, 4069, 4855, 43885, 12429, 1729, 15268, 15866, 39290, 5342, 24180, 13366, 2503, 13968, 35462, 15257, 59178, 59944, 18548, 15401, 22870, 24189, 39252, 33768, 9116, 35659, 38522, 36225, 7047, 35692, 44437, 22241, 43878, 12420, 36487, 3245, 2397, 24714, 17704, 13196, 55783, 47246, 15261, 57488, 38525, 15259, 59176, 13368, 22877, 5942, 13191, 55784, 47241, 15266, 10142, 2390, 12427, 36480, 1727, 22848, 22246, 28318, 34747, 7040, 35695, 13357, 17757, 1919, 15232, 26646, 5327, 13555, 5929, 40692, 43473, 25453, 7828, 23905, 12814, 4468, 17768, 9383, 5916, 39665, 11833, 47488, 22823, 33531, 13136, 43474, 5320, 47682, 43222, 1546, 40453, 38549, 26641, 15235, 44497, 43480, 3675, 5911, 11834, 22824, 7810, 12813, 47649, 14573, 10771, 17766, 3643, 10127, 54065, 47640, 44658, 13903, 49375, 5927, 38540, 26648, 23934, 3218, 38772, 17759, 1917, 49381, 6900, 26670, 3644, 44660, 13563, 26684, 36416, 37957, 59326, 38775, 38547, 6799, 22815, 5920, 38781, 36429, 49372, 13138, 5729, 13369, 39254, 22876, 38524, 57489, 59177, 15258, 13993, 22849, 13356, 34746, 35694, 7041, 24712, 53640, 17702, 47240, 35660, 55785, 39891, 15267, 12426, 36481, 4066, 59342, 35658, 38523, 6709, 24188, 13538, 22871, 5944, 39253, 33769, 10144, 2396, 12421, 36486, 47247, 15260, 17705, 35693, 7046, 44436, 36224, 43879, 22240, 17966, 12428, 4068, 43884, 39291, 15867, 12870, 15269, 15893, 13358, 34748, 2965, 22847, 59945, 15256, 21063, 35463, 10172, 57487, 17959, 13703, 22878, 19239, 20713, 24181, 36444, 5343, 5727, 139 ...

# %%
i=0
X_similar=[]
X_id_similar=[]
X_numpy=[]
for imageId in typeList:
#     print(imageId)
    Image_path=DATASET_PATH+list_directory[index]+"/"+str(imageId)+".jpg"
    image = cv2.imread(Image_path,cv2.IMREAD_GRAYSCALE)
    try:
        resized_img = cv2.resize(image, dsize=(28,28))
    except:
        print("can't read file: ", str(imageId)+".jpg")
    X_similar.append(resized_img)
    X_id_similar.append(imageId)
        
X_numpy = np.array(X_similar).reshape(-1, 28,28,1)
X_numpy = X_numpy/255
#print(X_numpy[0])

# %%
plt.imshow(X_similar[0])
plt.title(X_id_similar[0])
# Out:
# Text(0.5, 1.0, '9204')

# %% [markdown]
# # Calculating Vector Distance between Two Image

# %%
import math
def calculateDistance(i1, i2):
    return math.sqrt(np.sum((i1-i2)**2))

# %%
print(calculateDistance(numpy_image,X_numpy[0]))
# Out:
# 8.253265172365573

# %%
distance_list=[]
for i in range (0, len(X_numpy)):
    distance_list.append(calculateDistance(numpy_image,X_numpy[i]))

sorted_distance_list=distance_list.copy()
#print(distance_list)
sorted_distance_list.sort()

least_ten_distance=sorted_distance_list[0:10]
print(least_ten_distance)
index_distance=[]
for i in range (0, len(least_ten_distance)-1):
    if(least_ten_distance[i]!=least_ten_distance[i+1]):
        index_distance.append(distance_list.index(least_ten_distance[i]))

index_distance=index_distance[0:5]

print(index_distance)
# Out:
# [2.1883828750570906, 2.258983518299262, 2.259037980016208, 2.281038635118213, 2.290004692513522, 2.3650115238369525, 2.394704525713938, 2.414205683267821, 2.4167810099028393, 2.4753735169551496]
# [1751, 2438, 1956, 1788, 64]

# %% [markdown]
# # Recommended Items

# %%
# Image_path=DATASET_PATH+list_directory[index]+"/"+str(img_id)+".jpg"
# src = cv2.imread(Image_path)
# image = cv2.cvtColor(src, cv2.COLOR_BGR2RGB) 
plt.imshow(img)
plt.title(img_id)

fig=plt.figure()
fig.set_figheight(15)
fig.set_figwidth(15)
axis=[]
for i in range(0,len(index_distance)):
    print(X_id_similar[i])
    Image_path=DATASET_PATH+list_directory[index]+"/"+str(X_id_similar[index_distance[i]])+".jpg"
    src = cv2.imread(Image_path)
    image = cv2.cvtColor(src, cv2.COLOR_BGR2RGB) 
    axis.append(fig.add_subplot(1,5, i+1))
    subplot_title=str(X_id_similar[index_distance[i]])
    axis[-1].set_title(subplot_title)  
    plt.imshow(image)

fig.tight_layout()
plt.show()
# Out:
# 9204
# 39988
# 22198
# 29570
# 26538

# %% [markdown]
# ### UMAP

# %%
import umap
import umap.plot

nsamples, nx, ny, garbo = X.shape
X2 = X.reshape((nsamples,nx*ny))

# %%
dfU = df[~df.image.isin(Rej_imgs)]

UY = dfU.articleType

# %%
# 15 N Neighbors
embedder = umap.UMAP(n_neighbors=15, metric = 'cosine')

Utest = embedder.fit(X2)
umap.plot.points(Utest, labels=UY)

# %% [markdown]
# Now trying to change parameters

# %%
# 30 N Neighbors
embedder = umap.UMAP(n_neighbors=30, metric = "cosine")

Utest = embedder.fit(X2)

# %%
umap.plot.points(Utest, labels=UY)

# %%
# 50 N Neighbors, min_dist=.4
embedder = umap.UMAP(n_neighbors=50, metric = "cosine", min_dist=.4)

Utest = embedder.fit(X2)

# %%
umap.plot.points(Utest, labels=UY)

# %% [markdown]
# Overall, UMAP requires large amounts of parameter tuning to figure out which hyperparameters are most appropriate. Since its a newer technique, this can be quite challenging. UMAP seems to be more seperated and clustered than TSNE, which is what we would expect
