# %% [markdown]
# <a href="https://www.kaggle.com/hdvvip111/visual-product-recommendation-system-final-project?scriptVersionId=89158173" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Importing the Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Showing Directories with List

# %%
DATASET_PATH = "/kaggle/input/fashion-product-images-dataset/fashion-dataset/fashion-dataset/"
print(os.listdir(DATASET_PATH))
# Out:
# ['images.csv', 'images', 'styles.csv', 'styles']

# %% [markdown]
# # What is inside the image directory
# ## Observing some sample image

# %%
# what is inside the main directory
list_directory = os.listdir(DATASET_PATH)
print(list_directory)

# each time directory files gets reordered. That's why needed to find where images folder is.
index=0
for i in range (len(list_directory)):
    if list_directory[i]=="images":
        index=i
        break

# what is in the image directory
imageIndex = os.listdir(DATASET_PATH+list_directory[index])
# print(type(imageIndex))
head = 10

# collecting some samples in list
sampleImages = []

# showing indices
for i in range (head):
    sampleImages.append(imageIndex[i])
    print(sampleImages[i])

# choosing some samples to observe
fig=plt.figure()
fig.set_figheight(15)
fig.set_figwidth(15)
axis=[]
row = len(sampleImages)/2
col = row+1

for i in range (len(sampleImages)):
    Image_path=DATASET_PATH+list_directory[index]+"/"+sampleImages[i]
    src = cv2.imread(Image_path)
    image = cv2.cvtColor(src, cv2.COLOR_BGR2RGB) 
    axis.append(fig.add_subplot(row, col, i+1))
    subplot_title=sampleImages[i]
    axis[-1].set_title(subplot_title)  
    plt.imshow(image)

fig.tight_layout()
plt.show()
# Out:
# ['images.csv', 'images', 'styles.csv', 'styles']
# 31973.jpg
# 30778.jpg
# 19812.jpg
# 22735.jpg
# 38246.jpg
# 16916.jpg
# 52876.jpg
# 39500.jpg
# 44758.jpg
# 59454.jpg

# %% [markdown]
# # Problem1-We have no labeled data. Exploring styles.csv for more info.

# %%
df = pd.read_csv(DATASET_PATH + "styles.csv", nrows=1000, error_bad_lines=False)
df.head(10)
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 5   1855    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 6  30805    Men        Apparel     Topwear       Shirts      Green  Summer
# 7  26960  Women        Apparel     Topwear       Shirts     Purple  Summer
# 8  29114    Men    Accessories       Socks        Socks  Navy Blue  Summer
# 9  30039    Men    Accessories     Watches      Watches      Black  Winter
#
#    year   usage                             productDisplayName
# 0  2011  Casual               Turtle Check Men Navy Blue Shirt
# 1  2012  Casual             Peter England Men Party Blue Jeans
# 2  2016  Casual                       Titan Women Silver Watch
# 3  2011  Casual  Manchester United Men Solid Black Track Pants
# 4  2012  Casual                          Puma Men Grey T-shirt
# 5  2011  Casual           Inkfruit Mens Chain Reaction T-shirt
# 6  2012  Ethnic               Fabindia Men Striped Green Shirt
# 7  2012  Casual                  Jealous 21 Women Purple Shirt
# 8  2012  Casual                       Puma Men Pack of 3 Socks
# 9  2016  Casual                         Skagen Men Black Watch

# %% [markdown]
# # Image id matches with styles.csv file Id column.
# ## For ease of access, adding another column naming 'id.jpg'

# %%
df['image'] = df.apply(lambda row: str(row['id']) + ".jpg", axis=1)
df.head(10)
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 5   1855    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 6  30805    Men        Apparel     Topwear       Shirts      Green  Summer
# 7  26960  Women        Apparel     Topwear       Shirts     Purple  Summer
# 8  29114    Men    Accessories       Socks        Socks  Navy Blue  Summer
# 9  30039    Men    Accessories     Watches      Watches      Black  Winter
#
#    year   usage                             productDisplayName      image
# 0  2011  Casual               Turtle Check Men Navy Blue Shirt  15970.jpg
# 1  2012  Casual             Peter England Men Party Blue Jeans  39386.jpg
# 2  2016  Casual                       Titan Women Silver Watch  59263.jpg
# 3  2011  Casual  Manchester United Men Solid Black Track Pants  21379.jpg
# 4  2012  Casual                          Puma Men Grey T-shirt  53759.jpg
# 5  2011  Casual           Inkfruit Mens Chain Reaction T-shirt   1855.jpg
# 6  2012  Ethnic               Fabindia Men Striped Green Shirt  30805.jpg
# 7  2012  Casual                  Jealous 21 Women Purple Shirt  26960.jpg
# 8  2012  Casual                       Puma Men Pack of 3 Socks  29114.jpg
# 9  2016  Casual                         Skagen Men Black Watch  30039.jpg

# %% [markdown]
# # Building another dataframe with columns- image and article type

# %%
augmentedDataframe = pd.DataFrame({
    'filename': df['image'],
    'type': df['articleType']
})

# total number of entries in the dataframe
total_row = len(augmentedDataframe)
print('total row count: ', total_row)

augmentedDataframe.head(10)
# Out:
# total row count:  1000
#     filename         type
# 0  15970.jpg       Shirts
# 1  39386.jpg        Jeans
# 2  59263.jpg      Watches
# 3  21379.jpg  Track Pants
# 4  53759.jpg      Tshirts
# 5   1855.jpg      Tshirts
# 6  30805.jpg       Shirts
# 7  26960.jpg       Shirts
# 8  29114.jpg        Socks
# 9  30039.jpg      Watches

# %% [markdown]
# > # Created a list with unique values And added a column with their specified element position

# %%
unique_types = augmentedDataframe['type'].unique().tolist()
total_class = len(unique_types)
print(total_class)
print(unique_types)
print(unique_types[0])
print(unique_types.index(unique_types[0]))
augmentedDataframe['number_types'] = augmentedDataframe['type'].apply(lambda x: unique_types.index(x) if x in unique_types else 0)
augmentedDataframe.head(10)
# Out:
# 85
# ['Shirts', 'Jeans', 'Watches', 'Track Pants', 'Tshirts', 'Socks', 'Casual Shoes', 'Belts', 'Flip Flops', 'Handbags', 'Tops', 'Bra', 'Sandals', 'Shoe Accessories', 'Sweatshirts', 'Deodorant', 'Formal Shoes', 'Bracelet', 'Lipstick', 'Flats', 'Kurtas', 'Waistcoat', 'Sports Shoes', 'Shorts', 'Briefs', 'Sarees', 'Perfume and Body Mist', 'Heels', 'Sunglasses', 'Innerwear Vests', 'Pendant', 'Nail Polish', 'Laptop Bag', 'Scarves', 'Rain Jacket', 'Dresses', 'Night suits', 'Skirts', 'Wallets', 'Blazers', 'Ring', 'Kurta Sets', 'Clutches', 'Shrug', 'Backpacks', 'Caps', 'Trousers', 'Earrings', 'Camisoles', 'Boxers', 'Jewellery Set', 'Dupatta', 'Capris', 'Lip Gloss', 'Bath Robe', 'Mufflers', 'Tunics', 'Jackets', 'Trunk', 'Lounge Pants', 'Face Wash and Cleanser', 'Necklace and Chains', 'Duffel Bag', 'Sports Sandals', 'Foundation and Primer', 'Sweaters', 'Free Gifts', 'Trolley Bag', 'Tracksuits', 'Swimwear', 'Shoe Laces', 'Fragrance Gift Set', 'Bangle', 'Nightdress', 'Ties', 'Baby Dolls', 'Leggings', 'Highlighter and Blush', 'Travel Accessory', 'Kurtis', 'Mobile Pouch', 'Messenger Bag', 'Lip Care', 'Face Moisturisers', 'Compact']
# Shirts
# 0
#     filename         type  number_types
# 0  15970.jpg       Shirts             0
# 1  39386.jpg        Jeans             1
# 2  59263.jpg      Watches             2
# 3  21379.jpg  Track Pants             3
# 4  53759.jpg      Tshirts             4
# 5   1855.jpg      Tshirts             4
# 6  30805.jpg       Shirts             0
# 7  26960.jpg       Shirts             0
# 8  29114.jpg        Socks             5
# 9  30039.jpg      Watches             2

# %%
augmentedDataframe['type'].value_counts().head(50)
# Out:
# Tshirts                  142
# Shirts                    76
# Watches                   71
# Sports Shoes              55
# Casual Shoes              50
# Tops                      48
# Handbags                  45
# Kurtas                    32
# Flip Flops                29
# Sandals                   26
# Belts                     25
# Heels                     21
# Perfume and Body Mist     19
# Wallets                   19
# Flats                     19
# Formal Shoes              18
# Briefs                    17
# Sunglasses                17
# Jeans                     15
# Trousers                  14
# Backpacks                 13
# Lipstick                  13
# Bra                       12
# Deodorant                 12
# Caps                      10
# Sweatshirts                9
# Track Pants                8
# Dresses                    8
# Shorts                     8
# Socks                      8
# Innerwear Vests            8
# Clutches                   8
# Earrings                   7
# Tunics                     6
# Sarees                     6
# Bracelet                   6
# Capris                     5
# Mufflers                   4
# Jackets                    4
# Pendant                    4
# Night suits                3
# Sweaters                   3
# Lip Gloss                  3
# Messenger Bag              3
# Scarves                    3
# Ties                       3
# Jewellery Set              3
# Ring                       3
# Lounge Pants               3
# Kurta Sets                 3
# Name: type, dtype: int64

# %% [markdown]
# # Here total counting length is 108. Total number of type classes available 108.

# %%
plt.figure(figsize=(20,5))
augmentedDataframe['type'].value_counts().plot(kind='bar',x='type',y='filename')
plt.show()

# %% [markdown]
# # Starting with train and test data
# ## Inserting Image and Labels in numpy array

# %% [markdown]
# # Utility Function to get images and inserted into image array
# ## Start and Stop parameters will be useful train and test separation
#
# ## Here all X=image_data, Y=label_data

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
# Out:
# /opt/conda/lib/python3.7/site-packages/tqdm/std.py:666: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
def getData(start,stop):
    x_data = []
    y_data = []
    Rej_imgs = []
    #start = 0 #setting start parameter
    #stop = int(0.001*total_row) #setting stop parameter 
    
    for i in tqdm(range(start, stop)): 
        Image_path=DATASET_PATH+list_directory[index]+"/"+augmentedDataframe.loc[i,'filename']
#         print(augmentedDataframe.loc[i,'filename'])
        image = cv2.imread(Image_path,cv2.IMREAD_GRAYSCALE)
        try:
            resized_img = cv2.resize(image, dsize=(28, 28))
        except:
            print("Rejected Image: "+augmentedDataframe.loc[i,'filename'])
            Rej_imgs.append(augmentedDataframe.loc[i,'filename'])
            continue
        x_data.append(resized_img) 
        y_values = augmentedDataframe.loc[i,'number_types'] # earlier it was type
        y_data.append(y_values)
                
    return x_data, y_data,Rej_imgs

# %% [markdown]
# # Test of the function

# %%
X=[]
Y=[]
# for now start=0,stop=(0.001*total_row)
# total_row=count of rows in augmented data frame
start = 0
stop = int(0.001*total_row) # testing with 0.1% image of the dataset
X,Y,Rej_imgs =getData(start,stop)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))

# %%
def img_path(img):
    return DATASET_PATH+"/images/"+img

# %%
def load_image(img, resized_fac = 0.1):
    img     = cv2.imread(img_path(img))
    w, h, _ = img.shape
    resized = cv2.resize(img, (int(h*resized_fac), int(w*resized_fac)), interpolation = cv2.INTER_AREA)
    return resized

# %%
img_array = load_image(df.loc[0]['image'])
plt.imshow(cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB))

# %%
print(type(X))
# print(X[0])
plt.title(unique_types[Y[0]])
plt.imshow(X[0])
# Out:
# <class 'list'>

# %% [markdown]
# # Adding all the images to numpy array
# > # X=Image Array
# > # Y=Image Label Array

# %%
X=[]
Y=[]
start = 0
stop = total_row
X,Y,Rej_imgs=getData(start,stop)

# conversion into numpy array
X = np.array(X).reshape(-1, 28,28,1)
Y = np.array(Y)

# normalizing
X = X/255

# processing Y_train for dimension matching
Y = Y.reshape(len(X),)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))

# %%
print('Image Data Shape: ',X.shape)
print('Label Data Shape: ',Y.shape)
# Out:
# Image Data Shape:  (1000, 28, 28, 1)
# Label Data Shape:  (1000,)

# %% [markdown]
# # Now we got Image and Label added in the arrays. Next will be Spliting both train and test data.

# %% [markdown]
# > # Train,Test Division into 90:10
# > # Train,Validation Division into 90:10
# > Train, Validation, Test Percentage 80:10:10

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.1, random_state = 500)

# %%
print('Train Image Data Shape: ',X_train.shape)
print('Train Label Data Shape: ',Y_train.shape)
print('Test Image Data Shape: ',X_test.shape)
print('Test Label Data Shape: ',Y_test.shape)
# Out:
# Train Image Data Shape:  (900, 28, 28, 1)
# Train Label Data Shape:  (900,)
# Test Image Data Shape:  (100, 28, 28, 1)
# Test Label Data Shape:  (100,)

# %%
X_train, X_validate, Y_train, Y_validate = train_test_split(X_train, Y_train, test_size = 0.1, random_state = 500)

# %%
print('Train Image Data Shape: ',X_train.shape)
print('Train Label Data Shape: ',Y_train.shape)
print('Validation Image Data Shape: ',X_validate.shape)
print('Validation Label Data Shape: ',Y_validate.shape)
# Out:
# Train Image Data Shape:  (810, 28, 28, 1)
# Train Label Data Shape:  (810,)
# Validation Image Data Shape:  (90, 28, 28, 1)
# Validation Label Data Shape:  (90,)

# %% [markdown]
# > ## Splitting done with train and test and validation set.

# %% [markdown]
# # CNN Model Create

# %% [markdown]
# ># Importing Libraries

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Flatten, Dense, Dropout, LayerNormalization
from tensorflow.keras.layers import ReLU
from tensorflow.keras.optimizers import Adam
import os
import tensorflow as tf
import datetime, os
from tensorflow.keras.callbacks import TensorBoard

# %% [markdown]
# > # Creating sequential model with three layers

# %%
def build_model():
    cnn_model = Sequential()
    cnn_model.add(Conv2D(32, (3, 3), input_shape = (28,28,1)))
    cnn_model.add(LayerNormalization())
    cnn_model.add(ReLU())
    cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
    cnn_model.add(Dropout(0.25))

    cnn_model.add(Conv2D(64, (3, 3)))
    cnn_model.add(LayerNormalization())
    cnn_model.add(ReLU())
    cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
    cnn_model.add(Dropout(0.25))

    cnn_model.add(Conv2D(128, (3, 3)))
    cnn_model.add(LayerNormalization())
    cnn_model.add(ReLU())
    cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
    cnn_model.add(Dropout(0.25))

    cnn_model.add(Flatten())
    cnn_model.add(Dense(units = 512))
    cnn_model.add(LayerNormalization())
    cnn_model.add(ReLU())
    cnn_model.add(Dense(units = 512))
    cnn_model.add(LayerNormalization())
    cnn_model.add(ReLU())
    cnn_model.add(Dropout(0.25))
    
    cnn_model.add(Dense(units = total_class, activation = 'softmax'))
    return cnn_model

# %%
model=build_model()

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# layer_normalization (LayerNo (None, 26, 26, 32)        64
# _________________________________________________________________
# re_lu (ReLU)                 (None, 26, 26, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 11, 11, 64)        128
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 11, 11, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# layer_normalization_2 (Layer (None, 3, 3, 128)         256
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 3, 3, 128)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# layer_normalization_3 (Layer (None, 512)               1024
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# layer_normalization_4 (Layer (None, 512)               1024
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 85)                43605
# =================================================================
# Total params: 467,477
# Trainable params: 467,477
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def train_model(model):
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
    opt = Adam(learning_rate=1e-4)
    model.compile( loss ='sparse_categorical_crossentropy', optimizer='adam' ,metrics=['accuracy'])
    history = model.fit(X_train, Y_train, batch_size = 256, epochs = 150, verbose = 1,
                        callbacks=[callback], 
                        validation_data = (X_validate, Y_validate))
    
    return history
#     model.fit(X_train, Y_train, epochs=50, batch_size=512, validation_split=0.2)

# %%
training_history = train_model(model)
# Out:
# Epoch 1/150
# 4/4 [==============================] - 0s 109ms/step - loss: 4.3934 - accuracy: 0.0679 - val_loss: 3.6995 - val_accuracy: 0.1778
# Epoch 2/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.8323 - accuracy: 0.1025 - val_loss: 3.6409 - val_accuracy: 0.1778
# Epoch 3/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.7946 - accuracy: 0.0938 - val_loss: 3.6525 - val_accuracy: 0.1778
# Epoch 4/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.7436 - accuracy: 0.1099 - val_loss: 3.6722 - val_accuracy: 0.1778
# Epoch 5/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.7058 - accuracy: 0.0951 - val_loss: 3.6895 - val_accuracy: 0.1778
# Epoch 6/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.7262 - accuracy: 0.1012 - val_loss: 3.6948 - val_accuracy: 0.1778
# Epoch 7/150
# 4/4 [==============================] - 0s 16ms/step - loss: 3.7057 - accuracy: 0.1074 - val_loss: 3.6460 - val_accuracy: 0.1778
# Epoch 8/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.6788 - accuracy: 0.1173 - val_loss: 3.6270 - val_accuracy: 0.1778
# Epoch 9/150
# 4/4 [==============================] - 0s 16ms/step - loss: 3.6687 - accuracy: 0.1160 - val_loss: 3.5927 - val_accuracy: 0.1778
# Epoch 10/150
# 4/4 [==============================] - 0s 16ms/step - loss: 3.6618 - accuracy: 0.1210 - val_loss: 3.6148 - val_accuracy: 0.1778
# Epoch 11/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.6798 - accuracy: 0.1173 - val_loss: 3.6629 - val_accuracy: 0.1778
# Epoch 12/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.6794 - accuracy: 0.1296 - val_loss: 3.7004 - val_accuracy: 0.1778
# Epoch 13/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.6460 - accuracy: 0.1160 - val_loss: 3.7321 - val_accuracy: 0.0556
# Epoch 14/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.6519 - accuracy: 0.0963 - val_loss: 3.6701 - val_accuracy: 0.1778
# Epoch 15/150
# 4/4 [==============================] - 0s 16ms/step - loss: 3.6425 - accuracy: 0.1358 - val_loss: 3.6320 - val_accuracy: 0.1778
# Epoch 16/150
# 4/4 [==============================] - 0s 16ms/step - loss: 3.6342 - accuracy: 0.1395 - val_loss: 3.6180 - val_accuracy: 0.1889
# Epoch 17/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.6146 - accuracy: 0.1321 - val_loss: 3.5860 - val_accuracy: 0.2000
# Epoch 18/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.6192 - accuracy: 0.1321 - val_loss: 3.5614 - val_accuracy: 0.1778
# Epoch 19/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.5780 - accuracy: 0.1407 - val_loss: 3.5278 - val_accuracy: 0.1889
# Epoch 20/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.5315 - accuracy: 0.1494 - val_loss: 3.4995 - val_accuracy: 0.1000
# Epoch 21/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.4821 - accuracy: 0.1185 - val_loss: 3.3473 - val_accuracy: 0.1778
# Epoch 22/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.3956 - accuracy: 0.1580 - val_loss: 3.2693 - val_accuracy: 0.1556
# Epoch 23/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.2759 - accuracy: 0.1605 - val_loss: 3.0704 - val_accuracy: 0.2333
# Epoch 24/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.1769 - accuracy: 0.1815 - val_loss: 3.0676 - val_accuracy: 0.2444
# Epoch 25/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.0348 - accuracy: 0.1827 - val_loss: 2.8937 - val_accuracy: 0.2778
# Epoch 26/150
# 4/4 [==============================] - 0s 16ms/step - loss: 2.9584 - accuracy: 0.2049 - val_loss: 2.9909 - val_accuracy: 0.2778
# Epoch 27/150
# 4/4 [==============================] - 0s 16ms/step - loss: 2.9135 - accuracy: 0.2346 - val_loss: 2.8445 - val_accuracy: 0.3556
# Epoch 28/150
# 4/4 [==============================] - 0s 16ms/step - loss: 2.8564 - accuracy: 0.2198 - val_loss: 2.9654 - val_accuracy: 0.2556
# Epoch 29/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.7888 - accuracy: 0.2321 - val_loss: 2.7688 - val_accuracy: 0.2778
# Epoch 30/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.6995 - accuracy: 0.2494 - val_loss: 2.7726 - val_accuracy: 0.2889
# Epoch 31/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.6258 - accuracy: 0.2630 - val_loss: 2.7316 - val_accuracy: 0.3111
# Epoch 32/150
# 4/4 [==============================] - 0s 16ms/step - loss: 2.5677 - accuracy: 0.2852 - val_loss: 2.7680 - val_accuracy: 0.3111
# Epoch 33/150
# 4/4 [==============================] - 0s 16ms/step - loss: 2.5623 - accuracy: 0.2654 - val_loss: 2.6600 - val_accuracy: 0.2667
# Epoch 34/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.5026 - accuracy: 0.2790 - val_loss: 2.6572 - val_accuracy: 0.3444
# Epoch 35/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.4218 - accuracy: 0.3037 - val_loss: 2.5855 - val_accuracy: 0.3000
# Epoch 36/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.4034 - accuracy: 0.2975 - val_loss: 2.5684 - val_accuracy: 0.3111
# Epoch 37/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.3436 - accuracy: 0.3222 - val_loss: 2.5144 - val_accuracy: 0.2889
# Epoch 38/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.2914 - accuracy: 0.3457 - val_loss: 2.4958 - val_accuracy: 0.3111
# Epoch 39/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.2716 - accuracy: 0.3284 - val_loss: 2.4746 - val_accuracy: 0.4000
# Epoch 40/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.2081 - accuracy: 0.3556 - val_loss: 2.5433 - val_accuracy: 0.3333
# Epoch 41/150
# 4/4 [==============================] - 0s 16ms/step - loss: 2.1969 - accuracy: 0.3272 - val_loss: 2.4690 - val_accuracy: 0.3333
# Epoch 42/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.1422 - accuracy: 0.3568 - val_loss: 2.3981 - val_accuracy: 0.3778
# Epoch 43/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.0973 - accuracy: 0.3741 - val_loss: 2.3686 - val_accuracy: 0.4111
# Epoch 44/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.0680 - accuracy: 0.3963 - val_loss: 2.3005 - val_accuracy: 0.4000
# Epoch 45/150
# 4/4 [==============================] - 0s 16ms/step - loss: 2.0512 - accuracy: 0.3790 - val_loss: 2.3921 - val_accuracy: 0.3889
# Epoch 46/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.9683 - accuracy: 0.4049 - val_loss: 2.3871 - val_accuracy: 0.4333
# Epoch 47/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.9253 - accuracy: 0.3988 - val_loss: 2.2630 - val_accuracy: 0.4222
# Epoch 48/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.9125 - accuracy: 0.4025 - val_loss: 2.2433 - val_accuracy: 0.4222
# Epoch 49/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.8811 - accuracy: 0.4074 - val_loss: 2.3592 - val_accuracy: 0.3444
# Epoch 50/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.7971 - accuracy: 0.4210 - val_loss: 2.2784 - val_accuracy: 0.4111
# Epoch 51/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.7858 - accuracy: 0.4358 - val_loss: 2.1968 - val_accuracy: 0.4556
# Epoch 52/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.7719 - accuracy: 0.4346 - val_loss: 2.1530 - val_accuracy: 0.4667
# Epoch 53/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.7902 - accuracy: 0.4580 - val_loss: 2.2136 - val_accuracy: 0.4222
# Epoch 54/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.7421 - accuracy: 0.4642 - val_loss: 2.2405 - val_accuracy: 0.4444
# Epoch 55/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.6670 - accuracy: 0.4679 - val_loss: 2.1005 - val_accuracy: 0.4556
# Epoch 56/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.6075 - accuracy: 0.4889 - val_loss: 2.2369 - val_accuracy: 0.4889
# Epoch 57/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.6232 - accuracy: 0.4790 - val_loss: 2.1455 - val_accuracy: 0.4222
# Epoch 58/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.6457 - accuracy: 0.4741 - val_loss: 2.2659 - val_accuracy: 0.4111
# Epoch 59/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.5927 - accuracy: 0.4840 - val_loss: 2.1735 - val_accuracy: 0.4444
# Epoch 60/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.5827 - accuracy: 0.4840 - val_loss: 2.1944 - val_accuracy: 0.4444
# Epoch 61/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.5289 - accuracy: 0.4877 - val_loss: 2.1500 - val_accuracy: 0.4667
# Epoch 62/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.5274 - accuracy: 0.5099 - val_loss: 2.0923 - val_accuracy: 0.5111
# Epoch 63/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.4470 - accuracy: 0.5235 - val_loss: 2.1128 - val_accuracy: 0.4556
# Epoch 64/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.4929 - accuracy: 0.5049 - val_loss: 2.0500 - val_accuracy: 0.4556
# Epoch 65/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.4159 - accuracy: 0.5383 - val_loss: 2.0623 - val_accuracy: 0.4667
# Epoch 66/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.3729 - accuracy: 0.5395 - val_loss: 1.9954 - val_accuracy: 0.4889
# Epoch 67/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.3512 - accuracy: 0.5593 - val_loss: 2.1855 - val_accuracy: 0.4556
# Epoch 68/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3824 - accuracy: 0.5395 - val_loss: 2.0623 - val_accuracy: 0.4667
# Epoch 69/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.4220 - accuracy: 0.5407 - val_loss: 2.1022 - val_accuracy: 0.4667
# Epoch 70/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.3668 - accuracy: 0.5568 - val_loss: 2.0699 - val_accuracy: 0.4556
# Epoch 71/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3069 - accuracy: 0.5667 - val_loss: 2.0649 - val_accuracy: 0.4444
# Epoch 72/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.2592 - accuracy: 0.5938 - val_loss: 2.1762 - val_accuracy: 0.4667
# Epoch 73/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.2779 - accuracy: 0.5741 - val_loss: 2.0762 - val_accuracy: 0.4333
# Epoch 74/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.2345 - accuracy: 0.5963 - val_loss: 2.2113 - val_accuracy: 0.4667
# Epoch 75/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.2347 - accuracy: 0.5864 - val_loss: 2.0365 - val_accuracy: 0.5000
# Epoch 76/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.2397 - accuracy: 0.5926 - val_loss: 2.1057 - val_accuracy: 0.4667

# %% [markdown]
# # Model Evaluation

# %%
import pickle
with open('./training_history_pickle', "wb") as pkl_file:
        pickle.dump(training_history.history, pkl_file, pickle.HIGHEST_PROTOCOL)

# %%
with open('./training_history_pickle', "rb") as pkl_file:
        training_history_load = pickle.load(pkl_file)

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.plot(training_history_load['loss'], label='Train Loss')
plt.plot(training_history_load['val_loss'], label='Test Loss')
plt.legend()
plt.grid()
plt.title('Loss evaluation')

plt.subplot(2, 2, 2)
plt.plot(training_history_load['accuracy'], label='Train accuracy')
plt.plot(training_history_load['val_accuracy'], label='Test accuracy')
plt.legend()
plt.grid()
plt.title('Accuracy evaluation')
# Out:
# Text(0.5, 1.0, 'Accuracy evaluation')

# %% [markdown]
# ## Saving Model

# %%
model.save('visual_product_recommend.h5')

# %% [markdown]
# ## Load Model

# %%
from keras import models

# %%
pretrained_model = models.load_model('./visual_product_recommend.h5')
pretrained_model

# %% [markdown]
# # Predictions for the test data

# %%
predicted_classes = model.predict_classes(X_test)

# %%
import sklearn.metrics as metrics
print(metrics.classification_report(y_true=Y_test, y_pred=predicted_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.90      0.75        10
#            1       0.00      0.00      0.00         0
#            2       0.70      0.78      0.74         9
#            3       0.00      0.00      0.00         0
#            4       1.00      0.67      0.80        15
#            5       0.00      0.00      0.00         1
#            6       0.57      0.67      0.62         6
#            7       1.00      0.67      0.80         3
#            8       0.20      1.00      0.33         1
#            9       1.00      0.80      0.89         5
#           10       1.00      0.50      0.67         4
#           12       0.00      0.00      0.00         3
#           15       0.50      1.00      0.67         1
#           16       1.00      0.67      0.80         3
#           17       0.00      0.00      0.00         3
#           18       0.00      0.00      0.00         2
#           19       0.00      0.00      0.00         0
#           20       0.00      0.00      0.00         0
#           22       0.58      0.88      0.70         8
#           23       0.00      0.00      0.00         1
#           25       0.00      0.00      0.00         0
#           26       0.00      0.00      0.00         0
#           27       1.00      0.33      0.50         3
#           28       1.00      1.00      1.00         4
#           29       0.00      0.00      0.00         1
#           34       0.00      0.00      0.00         1
#           35       0.00      0.00      0.00         1
#           37       0.00      0.00      0.00         1
#           38       1.00      1.00      1.00         1
#           40       0.00      0.00      0.00         1
#           42       0.00      0.00      0.00         0
#           44       1.00      0.50      0.67         2
#           45       1.00      1.00      1.00         3
#           46       0.00      0.00      0.00         1
#           47       0.50      1.00      0.67         1
#           48       0.00      0.00      0.00         0
#           53       0.00      0.00      0.00         0
#           60       0.00      0.00      0.00         2
#           61       0.00      0.00      0.00         1
#           82       0.00      0.00      0.00         1
#           83       0.00      0.00      0.00         1
#
#     accuracy                           0.60       100
#    macro avg       0.33      0.33      0.31       100
# weighted avg       0.65      0.60      0.60       100
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#PC=PredictedClass #TC=TrueClass
L = 5
W = 5
fig, axes = plt.subplots(L, W, figsize = (12,12))
axes = axes.ravel()

for i in np.arange(0, L * W):  
    axes[i].imshow(X_test[i].reshape(28,28))
    axes[i].set_title(f"PC = {unique_types[predicted_classes[i]]}\n TC = {unique_types[Y_test[i]]}") #predicted_classes[i]:0.1f #Y_test[i]:0.1f
    axes[i].axis('off')
plt.subplots_adjust(wspace=0.5)

# %% [markdown]
# # Single Image Prediction & Find the Label of the Image

# %%
#augmentedDataframe.head(10)

# %%
def load_image(i):
    Image_path=DATASET_PATH+list_directory[index]+"/"+augmentedDataframe.loc[i,'filename']
    Image_id=augmentedDataframe.loc[i,'filename'].split(".")
    res=Image_id[0]
    image = cv2.imread(Image_path,cv2.IMREAD_COLOR)
    resized_img = cv2.resize(image, dsize=(224, 224))
    return resized_img,res

# %%
img,img_id = load_image(105)
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.title(img_id)
plt.imshow(img)

# %%
def make_prediction(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
    resized_img = cv2.resize(img, dsize=(28, 28))
    x_data = np.array(resized_img).reshape(-1, 28,28,1)
    x_data=x_data/255
#     print(x_data)
#     print(x_data.shape)
    result=pretrained_model.predict(x_data)
#     print(type(result))
#     print(np.argmax(result))
    return x_data,unique_types[np.argmax(result)]

# %%
numpy_image,result=make_prediction(img)
print(result)
# Out:
# Casual Shoes

# %%
#df.head(10)

# %% [markdown]
# # Starting Check for Similarity

# %%
typeList=[]
for i, row in df.iterrows(): 
    if(row["articleType"]==result):
        #print(row["id"],row["articleType"])
        if(img_id!=str(row["id"])):
            typeList.append(row['id'])

# %%
print(typeList)
# Out:
# [9204, 39988, 22198, 29570, 26538, 49495, 19311, 23849, 24250, 15517, 4140, 6425, 42270, 32751, 39943, 22705, 50741, 20856, 19772, 5896, 49492, 9031, 59056, 15379, 19329, 39944, 36130, 44510, 22702, 30233, 6422, 12507, 42045, 24257, 15510, 20894, 40971, 7364, 13073, 39972, 16165, 22162, 17043, 10266, 4343, 47501, 22196, 23878, 26536]

# %%
i=0
X_similar=[]
X_id_similar=[]
X_numpy=[]
for imageId in typeList:
#     print(imageId)
    Image_path=DATASET_PATH+list_directory[index]+"/"+str(imageId)+".jpg"
    image = cv2.imread(Image_path,cv2.IMREAD_GRAYSCALE)
    try:
        resized_img = cv2.resize(image, dsize=(28,28))
    except:
        print("can't read file: ", str(imageId)+".jpg")
    X_similar.append(resized_img)
    X_id_similar.append(imageId)
        
X_numpy = np.array(X_similar).reshape(-1, 28,28,1)
X_numpy = X_numpy/255
#print(X_numpy[0])

# %%
plt.imshow(X_similar[0])
plt.title(X_id_similar[0])
# Out:
# Text(0.5, 1.0, '9204')

# %% [markdown]
# # Calculating Vector Distance between Two Image

# %%
import math
def calculateDistance(i1, i2):
    return math.sqrt(np.sum((i1-i2)**2))

# %%
print(calculateDistance(numpy_image,X_numpy[0]))
# Out:
# 8.253265172365573

# %%
distance_list=[]
for i in range (0, len(X_numpy)):
    distance_list.append(calculateDistance(numpy_image,X_numpy[i]))

sorted_distance_list=distance_list.copy()
#print(distance_list)
sorted_distance_list.sort()

least_ten_distance=sorted_distance_list[0:10]
print(least_ten_distance)
index_distance=[]
for i in range (0, len(least_ten_distance)-1):
    if(least_ten_distance[i]!=least_ten_distance[i+1]):
        index_distance.append(distance_list.index(least_ten_distance[i]))

index_distance=index_distance[0:5]

print(index_distance)
# Out:
# [3.070475544472574, 3.439651636912394, 3.4630937137151063, 3.480247994804982, 3.612396955583077, 3.990873864485059, 3.992008549192286, 4.077958117338459, 4.081175547378451, 4.116393833563875]
# [37, 28, 22, 20, 32]

# %% [markdown]
# # Recommended Items

# %%
# Image_path=DATASET_PATH+list_directory[index]+"/"+str(img_id)+".jpg"
# src = cv2.imread(Image_path)
# image = cv2.cvtColor(src, cv2.COLOR_BGR2RGB) 
plt.imshow(img)
plt.title(img_id)

fig=plt.figure()
fig.set_figheight(15)
fig.set_figwidth(15)
axis=[]
for i in range(0,len(index_distance)):
    print(X_id_similar[i])
    Image_path=DATASET_PATH+list_directory[index]+"/"+str(X_id_similar[index_distance[i]])+".jpg"
    src = cv2.imread(Image_path)
    image = cv2.cvtColor(src, cv2.COLOR_BGR2RGB) 
    axis.append(fig.add_subplot(1,5, i+1))
    subplot_title=str(X_id_similar[index_distance[i]])
    axis[-1].set_title(subplot_title)  
    plt.imshow(image)

fig.tight_layout()
plt.show()
# Out:
# 9204
# 39988
# 22198
# 29570
# 26538

# %% [markdown]
# ## TSNE

# %%
from sklearn.manifold import TSNE
import time
import seaborn as sns
time_start = time.time()
tsne = TSNE(n_components=2, verbose=0, perplexity=5, n_iter=250)
tsne_results = tsne.fit_transform(X.reshape(X.shape[0],-1))
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))

df_reduced=df.iloc[:stop,]
df_reduced['tsne-2d-one'] = tsne_results[:,0]
df_reduced['tsne-2d-two'] = tsne_results[:,1]
plt.figure(figsize=(16,10))
sns.scatterplot(x="tsne-2d-one", y="tsne-2d-two",
                hue="articleType",
                data=df_reduced,
                legend="full",
                alpha=0.8)
# Out:
# t-SNE done! Time elapsed: 3.7525713443756104 seconds
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ## UMAP

# %%
import umap
import umap.plot

nsamples, nx, ny, garbo = X.shape
X2 = X.reshape((nsamples,nx*ny))

# %%
dfU = df[~df.image.isin(Rej_imgs)]

UY = dfU.articleType

# %%
# 15 N Neighbors
embedder = umap.UMAP(n_neighbors=15, metric = 'cosine')

Utest = embedder.fit(X2)
umap.plot.points(Utest, labels=UY)

# %% [markdown]
# Now trying to change parameters

# %%
# 30 N Neighbors
embedder = umap.UMAP(n_neighbors=30, metric = "cosine")

Utest = embedder.fit(X2)

# %%
umap.plot.points(Utest, labels=UY)

# %%
# 50 N Neighbors, min_dist=.4
embedder = umap.UMAP(n_neighbors=50, metric = "cosine", min_dist=.4)

Utest = embedder.fit(X2)

# %%
umap.plot.points(Utest, labels=UY)

# %% [markdown]
# Overall, UMAP requires large amounts of parameter tuning to figure out which hyperparameters are most appropriate. Since its a newer technique, this can be quite challenging. UMAP seems to be more seperated and clustered than TSNE, which is what we would expect
